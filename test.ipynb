# %%
import os
import warnings

# Suppress NumPy compatibility warnings during import
warnings.filterwarnings('ignore', message='.*_ARRAY_API.*')

os.add_dll_directory(r"C:\Users\ahmed\anaconda3\envs\lung_cancer\Library\bin")

try:
    from keras.preprocessing.image import ImageDataGenerator
    import numpy as np
    print("✓ Imports successful!")
    print(f"  NumPy: {np.__version__}")
except (AttributeError, ImportError) as e:
    if "_ARRAY_API" in str(e):
        print("⚠️  NumPy warning detected (harmless) - imports still successful")
    else:
        raise
# Out:
# ✓ Imports successful!
#   NumPy: 1.23.5

# %%
# Test data directory
data_dir = r"C:\Users\ahmed\ahmed\Desktop\lung-cancer-detection\data\lung_image_sets"

# Create test generator
test_datagen = ImageDataGenerator(rescale=1.0/255)

if os.path.exists(data_dir):
    test_gen = test_datagen.flow_from_directory(
        data_dir,
        target_size=(224, 224),
        batch_size=32,
        class_mode="categorical"
    )
    print(f"✓ Data generator created successfully!")
    print(f"  Classes: {test_gen.class_indices}")
else:
    print(f"✗ Data directory not found: {data_dir}")
# Out:
# Found 15000 images belonging to 3 classes.
# ✓ Data generator created successfully!
#   Classes: {'lung_aca': 0, 'lung_n': 1, 'lung_scc': 2}

# %%
# Verify NumPy version and TensorFlow compatibility
import numpy as np
import tensorflow as tf

print(f"NumPy version: {np.__version__}")
print(f"TensorFlow version: {tf.__version__}")
print(f"✓ All dependencies compatible!")
# Out:
# NumPy version: 1.23.5
# TensorFlow version: 2.10.0
# ✓ All dependencies compatible!

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
